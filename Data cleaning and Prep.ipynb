# %% [markdown]
# # GGIS 407 : Cyber GIS and Geospatial Data Science
# ## Geospatial Data Science Project – Data Cleaning and Preperation
# #### Date : 3-7-2023
# #### Author : Priyadarshini Satish

# %%
'''
Importing the CT List file which was contains state, city and country information along with min_age, max_age, condition being tested, 
and an ID. 
Data Source : https://clinicaltrials.gov/ct2/resources/download#DownloadStudy
'''
import pandas as pd
ct_list = pd.read_excel("CT_list.xlsx")
ct_list.head()
# Out:
#    Unnamed: 0       nct_id                                           ct_title  \
# 0           0  NCT00000102  Congenital Adrenal Hyperplasia: Calcium Channe...
# 1           1  NCT00000104  Does Lead Burden Alter Neuropsychological Deve...
# 2           2  NCT00000105  Vaccination With Tetanus and KLH to Assess Imm...
# 3           3  NCT00000106  41.8 Degree Centigrade Whole Body Hyperthermia...
# 4           4  NCT00000107  Body Water Content in Cyanotic Congenital Hear...
#
#                         condition  gender  min_age  max_age  \
# 0  Congenital Adrenal Hyperplasia     All     14.0     35.0
# 1                  Lead Poisoning  Female      0.0      NaN
# 2                          Cancer     All     18.0      NaN
# 3              Rheumatic Diseases     All     18.0     65.0
# 4       Heart Defects, Congenital     All     17.0     60.0
#
#                                        facility_name         city  \
# 0               Medical University of South Carolina   Charleston
# 1  Department of Neurology 420 Delaware St. SE, B...  Minneapolis
# 2  Division of Hematology, Oncology, and Transpla...  Minneapolis
# 3                         K4/666 CSC 600 Highland Av      Madison
# 4                              University of Vermont   Burlington
#
#             state        country
# 0  South Carolina  United States
# 1       Minnesota  United States
# 2       Minnesota  United States
# 3       Wisconsin  United States
# 4         Vermont  United States

# %%
'''
Examining the data set
'''
ct_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159579 entries, 0 to 159578
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     159579 non-null  int64
#  1   nct_id         159579 non-null  object
#  2   ct_title       159579 non-null  object
#  3   condition      159576 non-null  object
#  4   gender         159572 non-null  object
#  5   min_age        150042 non-null  float64
#  6   max_age        74931 non-null   float64
#  7   facility_name  155294 non-null  object
#  8   city           159579 non-null  object
#  9   state          159579 non-null  object
#  10  country        159579 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 13.4+ MB

# %%
'''
Subsetting for unique combinations of city, country and state then dropping duplicates
'''
loc_table = ct_list[['city','state','country']]
loc_table.drop_duplicates(inplace=True)
loc_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3042 entries, 0 to 159496
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   city     3042 non-null   object
#  1   state    3042 non-null   object
#  2   country  3042 non-null   object
# dtypes: object(3)
# memory usage: 95.1+ KB
# /cvmfs/cybergis.illinois.edu/software/conda/cybergisx/python3-0.9.0/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
'''
Checking if null values exist in city
'''
filtered_loc_table = loc_table[(pd.isna(loc_table['city']) == False) ]

# %%
'''
Cleaning city and state columns
'''

filtered_loc_table['city_cleaned'] = filtered_loc_table['city'].str.lower().str.replace(".","")
filtered_loc_table['state_cleaned'] = filtered_loc_table['state'].str.lower().str.replace(".","")
filtered_loc_table['city_state_cleaned'] = filtered_loc_table['city_cleaned'] + ', ' + filtered_loc_table['state_cleaned']
# Out:
# /tmp/ipykernel_293/3069894209.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   filtered_loc_table['city_cleaned'] = filtered_loc_table['city'].str.lower().str.replace(".","")
# /tmp/ipykernel_293/3069894209.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   filtered_loc_table['state_cleaned'] = filtered_loc_table['state'].str.lower().str.replace(".","")

# %%
filtered_loc_table['city_cleaned'].nunique(),filtered_loc_table['state_cleaned'].nunique()
# Out:
# (2600, 51)

# %%
'''
Reading the US city file which contains all cites in USA with latitude and longitude information.
Data Source: https://simplemaps.com/data/us-cities
'''
us_cities = pd.read_csv("uscities.csv")

# %%
us_cities.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4       Dallas       Dallas       TX       Texas        48113       Dallas
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18972871  10768.2  shape     False          True
# 1  34.1141 -118.4068    12121244   3267.6  shape     False          True
# 2  41.8375  -87.6866     8595181   4576.6  shape     False          True
# 3  25.7840  -80.2101     5711945   4945.7  shape     False          True
# 4  32.7935  -96.7667     5668165   1522.2  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# 1  America/Los_Angeles        1
# 2      America/Chicago        1
# 3     America/New_York        1
# 4      America/Chicago        1
#
#                                                 zips          id
# 0  11229 11226 11225 11224 11223 11221 11220 1138...  1840034016
# 1  90291 90293 90292 91316 91311 90035 90034 9003...  1840020491
# 2  60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3  33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4  75287 75098 75234 75254 75251 75252 75253 7503...  1840019440

# %%
'''
Cleaning the columns to match the structure of the CT_List table
'''

us_cities['city_cleaned'] = us_cities['city'].str.lower().str.replace(".","")
us_cities['state_cleaned'] = us_cities['state_name'].str.lower().str.replace(".","")
us_cities['city_state_cleaned'] = us_cities['city_cleaned'] + ', ' + us_cities['state_cleaned']
# Out:
# /tmp/ipykernel_293/129854764.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   us_cities['city_cleaned'] = us_cities['city'].str.lower().str.replace(".","")
# /tmp/ipykernel_293/129854764.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   us_cities['state_cleaned'] = us_cities['state_name'].str.lower().str.replace(".","")

# %%
'''
Merging the tables based on city and state
'''
merged_table = filtered_loc_table.merge(us_cities[['lat','lng','city_state_cleaned']], how = 'left', on='city_state_cleaned' )
merged_table
# Out:
#                     city           state        country        city_cleaned  \
# 0             Charleston  South Carolina  United States          charleston
# 1            Minneapolis       Minnesota  United States         minneapolis
# 2                Madison       Wisconsin  United States             madison
# 3             Burlington         Vermont  United States          burlington
# 4              Ann Arbor        Michigan  United States           ann arbor
# ...                  ...             ...            ...                 ...
# 3037  University Heights            Ohio  United States  university heights
# 3038             Oshkosh       Wisconsin  United States             oshkosh
# 3039          North Port         Florida  United States          north port
# 3040          E. Corning        New York  United States           e corning
# 3041           Lexington  South Carolina  United States           lexington
#
#        state_cleaned          city_state_cleaned      lat      lng
# 0     south carolina  charleston, south carolina  32.8168 -79.9687
# 1          minnesota      minneapolis, minnesota  44.9635 -93.2678
# 2          wisconsin          madison, wisconsin  43.0822 -89.3930
# 3            vermont         burlington, vermont  44.4876 -73.2316
# 4           michigan         ann arbor, michigan  42.2759 -83.7310
# ...              ...                         ...      ...      ...
# 3037            ohio    university heights, ohio  41.4948 -81.5350
# 3038       wisconsin          oshkosh, wisconsin  44.0227 -88.5619
# 3039         florida         north port, florida  27.0576 -82.1977
# 3040        new york         e corning, new york      NaN      NaN
# 3041  south carolina   lexington, south carolina  33.9890 -81.2202
#
# [3042 rows x 8 columns]

# %%
'''
Function for geocoding and retrieiving information from geocode meta data using geopy library on cities that did not get a location from the merge function
'''
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")
def get_location(dp):
    try:
        #to get location of city,state
        location = geolocator.geocode(dp, addressdetails=True)
        return location
    except:
        #if city, state is not found,return pd.NA
        #location = geolocator.geocode(str(dp).split()[-1], addressdetails=True)
        return pd.NA
    
def retrieve_info(dp,type):
    try:
        return dp.raw[str(type)]
    except:
        return pd.NA

# %%
'''
Code for retreiving city information from Geocode API. This is retrieved for all cities that could not be detected in the
table by searching for null values only

'''
for index, row in merged_table.loc[merged_table['lat'].isnull()].iterrows():
    print(merged_table.loc[index,'city_state_cleaned'])
    location = get_location(merged_table.loc[index,'city_state_cleaned'])
    merged_table.loc[index,'lng'] = retrieve_info(location,'lon')
    merged_table.loc[index,'lat'] = retrieve_info(location,'lat')
# Out:
# belmont, massachusetts
# brookline, massachusetts
# hyannis, massachusetts
# la jolla, california
# research triangle park, north carolina
# harbor city, california
# saint louis, missouri
# washington, dc, district of columbia
# raritan, new jersey
# groton, connecticut
# lajolla, california
# horsham, pennsylvania
# wellesley hills, massachusetts
# sherman oaks, california
# nutley, new jersey
# greenbrae, california
# whitehouse station, new jersey
# warren, new jersey
# ridgefield, connecticut
# peapack, new jersey
# wallingford, connecticut
# aniston, alabama
# fort sam houston, texas
# wethersfield, connecticut
# clinton township, michigan
# livingston, new jersey
# belleville, new jersey
# lakewood, new jersey
# warrington, pennsylvania
# winston salem, north carolina
# ft smith, arkansas
# east hanover, new jersey
# trumbull, connecticut
# sepulveda, california
# purchase, new york
# washington, dc, district of columbia
# jamaica plain, massachusetts
# west roxbury, massachusetts
# no little rock, washington
# baltimore, kansas
# bedford, massachusetts
# palo alto, michigan
# west los angeles, california
# hines, illinois
# no little rock, arkansas
# jackson, arkansas
# indianapolis, north carolina
# university park, pennsylvania
# freemont, california
# berkeley heights, new jersey
# scarborough, maine
# bridgewater, new jersey
# tuscon, arizona
# farmington, connecticut
# cohasset, massachusetts
# egleston, georgia
# watertown, massachusetts
# berkley, california
# homewood,, alabama
# phoenix,, arizona
# ft worth, texas
# glen oaks, new york
# berkely, california
# university of maryland, college park, maryland
# saint petersburg, florida
# piscataway, new jersey
# multiple locations throughout the united states, texas
# ft lauderdale, florida
# call for details, nebraska
# chestnut hill, massachusetts
# cities in alabama, alabama
# birmington, alabama
# newington, connecticut
# multiple locations, indiana
# central contact ft worth, texas
# richmond,, virginia
# san ysidro, california
# lower valley, yakima county, washington
# new york city, new york
# multiple locations throughout the us sponsored by alcon of, texas
# ft myers, florida
# la masa, california
# call for information, new jersey
# elk grove, illinois
# pamona, california
# investigative site, new jersey
# lexington,, kentucky
# birmgingham, alabama
# detroit,, michigan
# north attleboro, massachusetts
# brewster, massachusetts
# rockport, maine
# saint peters, missouri
# canyon country, california
# gwynn oak, maryland
# riverside, rhode island
# zuni, new mexico
# durham, new hampshire
# plymouth, new hampshire
# greenfield, massachusetts
# saint george, utah
# north grafton, massachusetts
# georgetown, district of columbia
# foxboro, massachusetts
# south dartmouth, massachusetts
# belcamp, maryland
# brick township, new jersey
# hanover, maryland
# scott air force base, illinois
# boyle heights, california
# hope, california
# multiple locations, washington
# barre, massachusetts
# ashland, massachusetts
# southington, connecticut
# georgetown, maine
# saint joseph, michigan
# beverly, kentucky
# boylston, massachusetts
# corona del mar, california
# saint charles, illinois
# lagrange, illinois
# maynard, massachusetts
# brookhaven, new york
# wakefield, rhode island
# dedham, massachusetts
# anaheim hills, california
# moorestown, new jersey
# centerville, massachusetts
# washington, massachusetts
# huntsville, north carolina
# boyds, maryland
# shirlington, virginia
# hixson, tennessee
# north chesterfield, virginia
# north haven, connecticut
# bayside, new york
# n augusta, south carolina
# marywood, illinois
# ijamsville, maryland
# cincinnati, indiana
# bala-cynwyd, pennsylvania
# e elmhurst, new york
# cape cañaveral, florida
# sault sainte-marie, michigan
# cranberry township, pennsylvania
# houston, california
# coconut grove, florida
# hyde park, new york
# greenport, new york
# base de la fuerza aérea whiteman, missouri
# acoma pueblo, new mexico
# saint johnsbury, vermont
# webster, new york
# washington township, new jersey
# s setauket, new york
# studio city, california
# moon, pennsylvania
# lagrangeville, new york
# chapel hill, virginia
# babylon, new york
# morgantown, virginia
# w fargo, north dakota
# pennsauken, new jersey
# rindge, new hampshire
# rosedale, new york
# leeds, massachusetts
# middletown, rhode island
# mount berry, georgia
# newton highlands, massachusetts
# toluca lake, california
# kingwood, texas
# paso robles, california
# east norriton, pennsylvania
# kykotsmovi, arizona
# mendham, new jersey
# new fairfield, connecticut
# hot springs national park, arkansas
# saint clairsville, ohio
# old saybrook, connecticut
# bloomfield township, michigan
# gainesville, new york
# south windsor, connecticut
# dover, pennsylvania
# candler, north carolina
# newtown square, pennsylvania
# castleton, vermont
# johnson, vermont
# monroe, connecticut
# norfolk, massachusetts
# saint clair shores, michigan
# baltimore, california
# north bergen, new jersey
# saint cloud, minnesota
# multiple locations, connecticut
# vestal, new york
# huntington, new york
# atlanta, arkansas
# camden, new york
# milton, massachusetts
# strasburg, pennsylvania
# bergen, new jersey
# mount laurel, new jersey
# oakwood, virginia
# minnesota, minnesota
# greenacres city, florida
# cromwell, connecticut
# astoria, new york
# lincoln, rhode island
# santa fe, california
# multiple locations, minnesota
# east saint louis, illinois
# sudbury, massachusetts
# s gate, california
# lā'ie, hawaii
# santa rosa beach, florida
# cheshire, connecticut
# seneca falls, new york
# madison, connecticut
# bar harbor, maine
# essex, connecticut
# fairfax, washington
# kingston, massachusetts
# scituate, massachusetts
# saint johns, florida
# helena, texas
# westlake, california
# leucadia, california
# rush, new york
# scott depot, west virginia
# little neck, new york
# holmdel, new jersey
# venice, california
# e corning, new york

# %%
'''
Checking how many rows still have no location information after running the geocode API. 
'''
merged_table.loc[merged_table['lng'].isnull()]
# Out:
#                                                  city           state  \
# 91                                            LaJolla      California
# 130                                           Aniston         Alabama
# 260                                      Indianapolis  North Carolina
# 349   Multiple Locations Throughout the United States           Texas
# 382                                  Call for Details        Nebraska
# ...                                               ...             ...
# 2514                               Multiple Locations      Washington
# 2689                 Base De La Fuerza Aérea Whiteman        Missouri
# 2902                               Multiple Locations     Connecticut
# 2935                                  Greenacres City         Florida
# 2963                               Multiple Locations       Minnesota
#
#             country                                     city_cleaned  \
# 91    United States                                          lajolla
# 130   United States                                          aniston
# 260   United States                                     indianapolis
# 349   United States  multiple locations throughout the united states
# 382   United States                                 call for details
# ...             ...                                              ...
# 2514  United States                               multiple locations
# 2689  United States                 base de la fuerza aérea whiteman
# 2902  United States                               multiple locations
# 2935  United States                                  greenacres city
# 2963  United States                               multiple locations
#
#        state_cleaned                                 city_state_cleaned   lat  \
# 91        california                                lajolla, california  <NA>
# 130          alabama                                   aniston, alabama  <NA>
# 260   north carolina                       indianapolis, north carolina  <NA>
# 349            texas  multiple locations throughout the united state...  <NA>
# 382         nebraska                         call for details, nebraska  <NA>
# ...              ...                                                ...   ...
# 2514      washington                     multiple locations, washington  <NA>
# 2689        missouri         base de la fuerza aérea whiteman, missouri  <NA>
# 2902     connecticut                    multiple locations, connecticut  <NA>
# 2935         florida                           greenacres city, florida  <NA>
# 2963       minnesota                      multiple locations, minnesota  <NA>
#
#        lng
# 91    <NA>
# 130   <NA>
# 260   <NA>
# 349   <NA>
# 382   <NA>
# ...    ...
# 2514  <NA>
# 2689  <NA>
# 2902  <NA>
# 2935  <NA>
# 2963  <NA>
#
# [150 rows x 8 columns]

# %%
'''
Defining a function to get the location information based on just the state variable
'''

def get_location_state(dp):
    try:
        location = geolocator.geocode(dp, addressdetails=True)
        return location
    except:
        pd.NA

# %%
'''
running that function on remaining rows
'''

for index, row in merged_table.loc[merged_table['lat'].isnull()].iterrows():
    print(index,merged_table.loc[index,'state_cleaned'])
    location = get_location_state(merged_table.loc[index,'state_cleaned'])
    merged_table.loc[index,'lng'] = retrieve_info(location,'lon')
    merged_table.loc[index,'lat'] = retrieve_info(location,'lat')
# Out:
# 91 california
# 130 alabama
# 260 north carolina
# 349 texas
# 382 nebraska
# 385 alabama
# 392 alabama
# 395 indiana
# 400 texas
# 416 texas
# 445 new jersey
# 470 new jersey
# 479 alabama
# 551 new jersey
# 557 california
# 574 georgia
# 576 california
# 587 minnesota
# 604 new jersey
# 614 california
# 618 california
# 625 california
# 645 alabama
# 658 alaska
# 695 colorado
# 698 california
# 740 hawaii
# 759 alabama
# 760 arizona
# 761 hawaii
# 797 alabama
# 876 california
# 922 maryland
# 936 maryland
# 948 california
# 961 arizona
# 969 pennsylvania
# 984 district of columbia
# 994 new jersey
# 1021 georgia
# 1034 new york
# 1057 kentucky
# 1067 texas
# 1077 florida
# 1083 indiana
# 1085 alabama
# 1096 california
# 1148 new mexico
# 1154 tennessee
# 1159 missouri
# 1177 california
# 1199 new mexico
# 1221 arizona
# 1233 california
# 1245 georgia
# 1281 washington
# 1297 missouri
# 1309 north carolina
# 1336 california
# 1369 texas
# 1371 california
# 1382 minnesota
# 1397 north carolina
# 1406 virginia
# 1409 california
# 1438 michigan
# 1450 missouri
# 1454 alabama
# 1456 kansas
# 1461 california
# 1463 ohio
# 1467 mississippi
# 1478 utah
# 1491 alabama
# 1530 new jersey
# 1533 georgia
# 1536 minnesota
# 1546 arizona
# 1573 new mexico
# 1582 kansas
# 1591 new jersey
# 1592 wisconsin
# 1599 arkansas
# 1610 connecticut
# 1615 alabama
# 1622 indiana
# 1627 massachusetts
# 1631 ohio
# 1642 florida
# 1649 arizona
# 1663 arizona
# 1667 illinois
# 1724 kentucky
# 1729 california
# 1756 delaware
# 1772 arkansas
# 1778 pennsylvania
# 1779 california
# 1794 connecticut
# 1841 california
# 1852 arizona
# 1859 ohio
# 1862 alabama
# 1876 pennsylvania
# 1878 alabama
# 1904 california
# 1909 pennsylvania
# 1912 maryland
# 1920 arizona
# 1922 arizona
# 1974 colorado
# 1977 mississippi
# 1978 arkansas
# 2002 pennsylvania
# 2015 florida
# 2016 florida
# 2021 north carolina
# 2031 texas
# 2045 texas
# 2055 wisconsin
# 2056 california
# 2060 oregon
# 2061 texas
# 2077 texas
# 2089 indiana
# 2096 georgia
# 2103 connecticut
# 2121 alaska
# 2134 alabama
# 2146 arizona
# 2149 indiana
# 2151 washington
# 2156 texas
# 2168 oregon
# 2190 alabama
# 2203 pennsylvania
# 2204 maryland
# 2219 texas
# 2232 texas
# 2248 florida
# 2253 florida
# 2321 pennsylvania
# 2341 missouri
# 2376 georgia
# 2379 new jersey
# 2514 washington
# 2689 missouri
# 2902 connecticut
# 2935 florida
# 2963 minnesota

# %%
'''
Merging data with parent table CT List
'''

final_merged_list = pd.merge(ct_list,merged_table[['lat','lng','city','state']], how= 'left' , on=['city','state'])
final_merged_list.head()
# Out:
#    Unnamed: 0       nct_id                                           ct_title  \
# 0           0  NCT00000102  Congenital Adrenal Hyperplasia: Calcium Channe...
# 1           1  NCT00000104  Does Lead Burden Alter Neuropsychological Deve...
# 2           2  NCT00000105  Vaccination With Tetanus and KLH to Assess Imm...
# 3           3  NCT00000106  41.8 Degree Centigrade Whole Body Hyperthermia...
# 4           4  NCT00000107  Body Water Content in Cyanotic Congenital Hear...
#
#                         condition  gender  min_age  max_age  \
# 0  Congenital Adrenal Hyperplasia     All     14.0     35.0
# 1                  Lead Poisoning  Female      0.0      NaN
# 2                          Cancer     All     18.0      NaN
# 3              Rheumatic Diseases     All     18.0     65.0
# 4       Heart Defects, Congenital     All     17.0     60.0
#
#                                        facility_name         city  \
# 0               Medical University of South Carolina   Charleston
# 1  Department of Neurology 420 Delaware St. SE, B...  Minneapolis
# 2  Division of Hematology, Oncology, and Transpla...  Minneapolis
# 3                         K4/666 CSC 600 Highland Av      Madison
# 4                              University of Vermont   Burlington
#
#             state        country      lat      lng
# 0  South Carolina  United States  32.8168 -79.9687
# 1       Minnesota  United States  44.9635 -93.2678
# 2       Minnesota  United States  44.9635 -93.2678
# 3       Wisconsin  United States  43.0822  -89.393
# 4         Vermont  United States  44.4876 -73.2316

# %%
'''
checking for null values in longitude
'''

final_merged_list['lng'].isnull().sum()
# Out:
# 0

# %%
'''
exporting to excel for use in next stage of analysis
'''

final_merged_list.to_excel("CT_list_geocode.xlsx")
